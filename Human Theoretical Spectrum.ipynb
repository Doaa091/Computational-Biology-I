# %%
from pyopenms import *
import matplotlib.pyplot as plt
dig = ProteaseDigestion()
dig.getEnzymeName() # Trypsin
bsa = "".join([l.strip() for l in open("uniprot-yourlist_M20211212F248CABF64506F29A91F8037F07B67D135F235C.fasta").readlines()[1:]])
bsa = AASequence.fromString(bsa)
# create all digestion products
result = []
dig.digest(bsa, result)
print(len(result))
for i in result:
  Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
  spectrum= MSSpectrum()
  param = Param()
  param.setValue("add_b_ions", "true")
  param.setValue("add_metainfo", "true")
  Theoretical_Spectrum_Generator.setParameters(param)
  Theoretical_Spectrum_Generator.getSpectrum(spectrum, i, 1, 1)
  plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
  plt.xlabel("m/z")
  plt.ylabel("intensity")
# Out:
# 110

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[1], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[2], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[3], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[4], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[5], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[6], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[7], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[8], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[9], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')

# %%
Theoretical_Spectrum_Generator = TheoreticalSpectrumGenerator()
spectrum= MSSpectrum()
param = Param()
param.setValue("add_b_ions", "true")
param.setValue("add_metainfo", "true")
Theoretical_Spectrum_Generator.setParameters(param)
Theoretical_Spectrum_Generator.getSpectrum(spectrum,result[10], 1, 1)
plt.bar(spectrum.get_peaks()[0], spectrum.get_peaks()[1], snap=False)
plt.xlabel("m/z")
plt.ylabel("intensity")
# Out:
# Text(0, 0.5, 'intensity')
